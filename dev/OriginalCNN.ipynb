# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import os
import zipfile
import pathlib
import matplotlib.image as mpimg

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# each image is an array of individual img arrays :o
import pathlib
full_path = os.path.abspath("/content/drive/MyDrive/DataMiningProject")
data_dir = tf.keras.utils.get_file('animals2.zip', f'file://{full_path}', extract=True)

parent_dir = pathlib.Path(data_dir).with_suffix('').parent
data_dir = parent_dir / 'animals'
print(data_dir)
# Out:
# Downloading data from file:///content/drive/Shareddrives/CSC_422_Project/animals2.zip
# 106510318/106510318 [==============================] - 1s 0us/step
# /root/.keras/datasets/animals

# %%
batch_size = 50
img_height, img_width = 128, 128

training_data = tf.keras.utils.image_dataset_from_directory(data_dir, validation_split=0.15, subset="training", seed=123, image_size=(img_height, img_width), batch_size=batch_size)
testing_data = tf.keras.utils.image_dataset_from_directory(data_dir, validation_split=0.15, subset="validation", seed=123, image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 5419 files belonging to 90 classes.
# Using 4607 files for training.
# Found 5419 files belonging to 90 classes.
# Using 812 files for validation.

# %%
normalization_layer = layers.Rescaling(1./255)
normalized_ds = training_data.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(data_dir, validation_split=0.15, subset="validation", seed=123, image_size=(img_height, img_width), batch_size=batch_size)
class_names = train_ds.class_names
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# Found 5419 files belonging to 90 classes.
# Using 812 files for validation.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = training_data.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = testing_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 90)                11610
#
# =================================================================
# Total params: 2132474 (8.13 MB)
# Trainable params: 2132474 (8.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs=25
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/25
# 93/93 [==============================] - 2s 26ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 7.6532 - val_accuracy: 0.3448
# Epoch 2/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0055 - accuracy: 0.9996 - val_loss: 7.7260 - val_accuracy: 0.3436
# Epoch 3/25
# 93/93 [==============================] - 2s 16ms/step - loss: 0.0050 - accuracy: 0.9996 - val_loss: 7.7741 - val_accuracy: 0.3461
# Epoch 4/25
# 93/93 [==============================] - 2s 16ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 7.7366 - val_accuracy: 0.3473
# Epoch 5/25
# 93/93 [==============================] - 2s 16ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 7.8077 - val_accuracy: 0.3448
# Epoch 6/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0045 - accuracy: 0.9996 - val_loss: 7.7526 - val_accuracy: 0.3461
# Epoch 7/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 7.7764 - val_accuracy: 0.3485
# Epoch 8/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 7.7455 - val_accuracy: 0.3485
# Epoch 9/25
# 93/93 [==============================] - 1s 14ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 7.8109 - val_accuracy: 0.3510
# Epoch 10/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 7.8034 - val_accuracy: 0.3461
# Epoch 11/25
# 93/93 [==============================] - 2s 16ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 7.7828 - val_accuracy: 0.3510
# Epoch 12/25
# 93/93 [==============================] - 1s 14ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 7.9103 - val_accuracy: 0.3534
# Epoch 13/25
# 93/93 [==============================] - 1s 14ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 7.8544 - val_accuracy: 0.3547
# Epoch 14/25
# 93/93 [==============================] - 1s 14ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 7.9860 - val_accuracy: 0.3498
# Epoch 15/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 8.0619 - val_accuracy: 0.3534
# Epoch 16/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 8.1387 - val_accuracy: 0.3571
# Epoch 17/25
# 93/93 [==============================] - 1s 16ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 8.1688 - val_accuracy: 0.3584
# Epoch 18/25
# 93/93 [==============================] - 2s 16ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 8.1811 - val_accuracy: 0.3485
# Epoch 19/25
# 93/93 [==============================] - 1s 16ms/step - loss: 9.2513e-04 - accuracy: 0.9998 - val_loss: 8.2158 - val_accuracy: 0.3559
# Epoch 20/25
# 93/93 [==============================] - 1s 16ms/step - loss: 8.5847e-04 - accuracy: 0.9998 - val_loss: 8.3439 - val_accuracy: 0.3547
# Epoch 21/25
# 93/93 [==============================] - 1s 15ms/step - loss: 9.8598e-04 - accuracy: 0.9998 - val_loss: 8.3894 - val_accuracy: 0.3571
# Epoch 22/25
# 93/93 [==============================] - 1s 15ms/step - loss: 9.2441e-04 - accuracy: 0.9998 - val_loss: 8.4431 - val_accuracy: 0.3522
# Epoch 23/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 8.3310 - val_accuracy: 0.3522
# Epoch 24/25
# 93/93 [==============================] - 1s 14ms/step - loss: 8.2134e-04 - accuracy: 0.9998 - val_loss: 8.4461 - val_accuracy: 0.3584
# Epoch 25/25
# 93/93 [==============================] - 1s 15ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 8.4473 - val_accuracy: 0.3559

# %%
parent_dir = pathlib.Path(data_dir).with_suffix('').parent
data_dir = parent_dir / 'animals'
imgPath = f'{str(data_dir)}/tiger/048cbe616d.png'

img = mpimg.imread(imgPath) #Replace "image.jpg" with the path of your image
plt.imshow(img)

# %%
img = tf.keras.utils.load_img(imgPath, target_size=(img_height, img_width))
img_array = tf.expand_dims(img, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image is most likely a(n) {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 265ms/step
# This image is most likely a(n) orangutan with a 37.52 percent confidence.
